# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("general_data.csv")

# %%
data.shape
# Out:
# (4410, 24)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
# 2                 1.0      Y                15              8
# 3                 3.0      Y                11              8
# 4                 4.0      Y                12              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
# 2                 3               5.0                      2               5
# 3                 3              13.0                      5               8
# 4                 2               9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4
#
# [5 rows x 24 columns]

# %%
columns = " -|- ".join(list(data.columns))
columns
# Out:
# 'Age -|- Attrition -|- BusinessTravel -|- Department -|- DistanceFromHome -|- Education -|- EducationField -|- EmployeeCount -|- EmployeeID -|- Gender -|- JobLevel -|- JobRole -|- MaritalStatus -|- MonthlyIncome -|- NumCompaniesWorked -|- Over18 -|- PercentSalaryHike -|- StandardHours -|- StockOptionLevel -|- TotalWorkingYears -|- TrainingTimesLastYear -|- YearsAtCompany -|- YearsSinceLastPromotion -|- YearsWithCurrManager'

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
data = data.drop_duplicates()

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeID                   int64
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# Over18                      object
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
# now we need to analyze the numerical variables:
ToKeep = []
for i in range(len(data_types.index)):
    if str(data_types[i]) != "object":
        ToKeep.append(data_types.index[i])
    else:
        continue
ToKeep.remove("EmployeeID")
data_nums = data[ToKeep]
ToKeep
# Out:
# ['Age',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeCount',
#  'JobLevel',
#  'MonthlyIncome',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'YearsAtCompany',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
from scipy.stats import iqr
iqr_list =[]
for i in ToKeep:
    q = iqr(data[i])
    iqr_list.append(q)

dnmo = data_nums.mode().sum()
dnme = data_nums.median()
dnmm = data_nums.mean()
dnms = data_nums.std()
dnmv = data_nums.var()
dnmk = data_nums.kurt()
dnmw = data_nums.skew()
dataset = pd.DataFrame({'mode': dnmo, "mean": dnmm ,'median': dnme, 'standard_deviation' : dnms,'variance' : dnmv,'kurtosis' : dnmk
                        ,'skewness': dnmw}, columns=['mode','mean', 'median','standard_deviation','variance','kurtosis','skewness'])
dataset["IQR"] = iqr_list
dataset
# Out:
#                             mode          mean   median  standard_deviation  \
# Age                         35.0     36.923810     36.0            9.133301
# DistanceFromHome             2.0      9.192517      7.0            8.105026
# Education                    3.0      2.912925      3.0            1.023933
# EmployeeCount                1.0      1.000000      1.0            0.000000
# JobLevel                     1.0      2.063946      2.0            1.106689
# MonthlyIncome            23420.0  65029.312925  49190.0        47068.888559
# NumCompaniesWorked           1.0      2.694830      2.0            2.498887
# PercentSalaryHike           11.0     15.209524     14.0            3.659108
# StandardHours                8.0      8.000000      8.0            0.000000
# StockOptionLevel             0.0      0.793878      1.0            0.851883
# TotalWorkingYears           10.0     11.279936     10.0            7.782222
# TrainingTimesLastYear        2.0      2.799320      3.0            1.288978
# YearsAtCompany               5.0      7.008163      5.0            6.125135
# YearsSinceLastPromotion      0.0      2.187755      1.0            3.221699
# YearsWithCurrManager         2.0      4.123129      3.0            3.567327
#
#                              variance  kurtosis  skewness      IQR
# Age                      8.341719e+01 -0.405951  0.413005     13.0
# DistanceFromHome         6.569144e+01 -0.227045  0.957466     12.0
# Education                1.048438e+00 -0.560569 -0.289484      2.0
# EmployeeCount            0.000000e+00  0.000000  0.000000      0.0
# JobLevel                 1.224760e+00  0.395525  1.024703      2.0
# MonthlyIncome            2.215480e+09  1.000232  1.368884  54690.0
# NumCompaniesWorked       6.244436e+00  0.007287  1.026767      NaN
# PercentSalaryHike        1.338907e+01 -0.302638  0.820569      6.0
# StandardHours            0.000000e+00  0.000000  0.000000      0.0
# StockOptionLevel         7.257053e-01  0.361086  0.968321      1.0
# TotalWorkingYears        6.056298e+01  0.912936  1.116832      NaN
# TrainingTimesLastYear    1.661465e+00  0.491149  0.552748      1.0
# YearsAtCompany           3.751728e+01  3.923864  1.763328      6.0
# YearsSinceLastPromotion  1.037935e+01  3.601761  1.982939      3.0
# YearsWithCurrManager     1.272582e+01  0.167949  0.832884      5.0

# %%
data_nums.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount     JobLevel  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0     2.063946
# std       9.133301          8.105026     1.023933            0.0     1.106689
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0     1.000000
# 50%      36.000000          7.000000     3.000000            1.0     2.000000
# 75%      43.000000         14.000000     4.000000            1.0     3.000000
# max      60.000000         29.000000     5.000000            1.0     5.000000
#
#        MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# count    4410.000000         4391.000000        4410.000000         4410.0
# mean    65029.312925            2.694830          15.209524            8.0
# std     47068.888559            2.498887           3.659108            0.0
# min     10090.000000            0.000000          11.000000            8.0
# 25%     29110.000000            1.000000          12.000000            8.0
# 50%     49190.000000            2.000000          14.000000            8.0
# 75%     83800.000000            4.000000          18.000000            8.0
# max    199990.000000            9.000000          25.000000            8.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       4410.000000        4401.000000            4410.000000
# mean           0.793878          11.279936               2.799320
# std            0.851883           7.782222               1.288978
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# count     4410.000000              4410.000000           4410.000000
# mean         7.008163                 2.187755              4.123129
# std          6.125135                 3.221699              3.567327
# min          0.000000                 0.000000              0.000000
# 25%          3.000000                 0.000000              2.000000
# 50%          5.000000                 1.000000              3.000000
# 75%          9.000000                 3.000000              7.000000
# max         40.000000                15.000000             17.000000

# %%
fig, axs = plt.subplots(1,4);
fig.suptitle('BoxPlots of Variables');
axs[0].boxplot (data["Age"]);
axs[0].set_title('Age');
axs[1].boxplot (data["MonthlyIncome"]);
axs[1].set_title('Monthly Income');
axs[2].boxplot (data["YearsAtCompany"]);
axs[2].set_title('Years At Company');
axs[3].boxplot (data["DistanceFromHome"]);
axs[3].set_title('Distance From Home');
fig.subplots_adjust(left=0.1, wspace=1.6);

# %% [markdown]
# #No outliers detected in Age and Distance variables, but Monthly Income and Years At Company are having several outliers;

# %%
pd.crosstab(data.JobLevel, data.Attrition)
# Out:
# Attrition    No  Yes
# JobLevel
# 1          1377  252
# 2          1317  285
# 3           558   96
# 4           267   51
# 5           180   27

# %%
plt.hist(data_nums["MonthlyIncome"], bins = 20); # a right skewed data;

# %%
pd.crosstab(data["Department"], data["Attrition"])
# Out:
# Attrition                 No  Yes
# Department
# Human Resources          132   57
# Research & Development  2430  453
# Sales                   1137  201

# %%
attr = data.Attrition.unique()
plt.hist([data.loc[data.Attrition == x, 'MonthlyIncome'] for x in attr], label=attr);
plt.legend(attr);

# %%
attr = data.Attrition.unique()
plt.hist([data.loc[data.Attrition == x, 'DistanceFromHome'] for x in attr], label=attr);
plt.legend(attr);
#it is surprising that the employees who have lived relatively closer to the company, had more attritions;

# %%
attr = data.Attrition.unique()
plt.hist([data.loc[data.Attrition == x, 'Education'] for x in attr], label=attr);
plt.legend(attr);
#people in the middle education level are more likely to live the company;

# %%
attr = data.Attrition.unique()
plt.hist([data.loc[data.Attrition == x, 'PercentSalaryHike'] for x in attr], label=attr);
plt.legend(attr);
#it is more likely for people with low percentage hike in their salary to live the company;

# %%
data_nums_cor = data_nums.drop(["StandardHours","EmployeeCount"], axis = 1)
cor_tab = data_nums_cor.corr()
cor_tab
# Out:
#                               Age  DistanceFromHome  Education  JobLevel  \
# Age                      1.000000          0.006963  -0.035706 -0.002884
# DistanceFromHome         0.006963          1.000000  -0.008638 -0.037329
# Education               -0.035706         -0.008638   1.000000  0.045746
# JobLevel                -0.002884         -0.037329   0.045746  1.000000
# MonthlyIncome           -0.044314         -0.021607   0.006410  0.047316
# NumCompaniesWorked       0.299243         -0.013843  -0.016250 -0.009875
# PercentSalaryHike       -0.033137          0.038125  -0.040531  0.010973
# StockOptionLevel        -0.031753          0.011169   0.001261  0.000993
# TotalWorkingYears        0.680661          0.009374  -0.010717 -0.036957
# TrainingTimesLastYear   -0.027308         -0.009001   0.010472 -0.032500
# YearsAtCompany           0.311309          0.031684   0.006080 -0.064219
# YearsSinceLastPromotion  0.216513          0.002290   0.022490 -0.060811
# YearsWithCurrManager     0.202089          0.021584   0.005358 -0.055251
#
#                          MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# Age                          -0.044314            0.299243          -0.033137
# DistanceFromHome             -0.021607           -0.013843           0.038125
# Education                     0.006410           -0.016250          -0.040531
# JobLevel                      0.047316           -0.009875           0.010973
# MonthlyIncome                 1.000000           -0.020726           0.004325
# NumCompaniesWorked           -0.020726            1.000000           0.030860
# PercentSalaryHike             0.004325            0.030860           1.000000
# StockOptionLevel              0.026930            0.017163           0.012548
# TotalWorkingYears            -0.033787            0.238807          -0.018736
# TrainingTimesLastYear         0.050112           -0.032286          -0.037392
# YearsAtCompany                0.000995           -0.117959          -0.029707
# YearsSinceLastPromotion       0.065219           -0.036656          -0.029542
# YearsWithCurrManager          0.024304           -0.109667          -0.040864
#
#                          StockOptionLevel  TotalWorkingYears  \
# Age                             -0.031753           0.680661
# DistanceFromHome                 0.011169           0.009374
# Education                        0.001261          -0.010717
# JobLevel                         0.000993          -0.036957
# MonthlyIncome                    0.026930          -0.033787
# NumCompaniesWorked               0.017163           0.238807
# PercentSalaryHike                0.012548          -0.018736
# StockOptionLevel                 1.000000           0.002694
# TotalWorkingYears                0.002694           1.000000
# TrainingTimesLastYear           -0.069902          -0.040762
# YearsAtCompany                   0.007886           0.627703
# YearsSinceLastPromotion          0.019063           0.404444
# YearsWithCurrManager             0.017757           0.458800
#
#                          TrainingTimesLastYear  YearsAtCompany  \
# Age                                  -0.027308        0.311309
# DistanceFromHome                     -0.009001        0.031684
# Education                             0.010472        0.006080
# JobLevel                             -0.032500       -0.064219
# MonthlyIncome                         0.050112        0.000995
# NumCompaniesWorked                   -0.032286       -0.117959
# PercentSalaryHike                    -0.037392       -0.029707
# StockOptionLevel                     -0.069902        0.007886
# TotalWorkingYears                    -0.040762        0.627703
# TrainingTimesLastYear                 1.000000       -0.007894
# YearsAtCompany                       -0.007894        1.000000
# YearsSinceLastPromotion               0.016121        0.618409
# YearsWithCurrManager                 -0.013270        0.769212
#
#                          YearsSinceLastPromotion  YearsWithCurrManager
# Age                                     0.216513              0.202089
# DistanceFromHome                        0.002290              0.021584
# Education                               0.022490              0.005358
# JobLevel                               -0.060811             -0.055251
# MonthlyIncome                           0.065219              0.024304
# NumCompaniesWorked                     -0.036656             -0.109667
# PercentSalaryHike                      -0.029542             -0.040864
# StockOptionLevel                        0.019063              0.017757
# TotalWorkingYears                       0.404444              0.458800
# TrainingTimesLastYear                   0.016121             -0.013270
# YearsAtCompany                          0.618409              0.769212
# YearsSinceLastPromotion                 1.000000              0.510224
# YearsWithCurrManager                    0.510224              1.000000

# %%
mask = np.triu(np.ones_like(cor_tab, dtype=np.bool))
f, ax = plt.subplots(figsize=(10, 10))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(cor_tab, mask=mask, cmap=cmap, vmax=.79,vmin= -.2, center=0.1,
            square=True, linewidths=.4, cbar_kws={"shrink": .4});

# %%
# generating a list of correlation to find out the highest correlations:
cor_shape = list(range(int(cor_tab.shape[0])))
tlist = []
for x in cor_shape: #filling the diagonal values with zeros
    for x in cor_shape:
        cor_tab.iloc[x,x] = 0
for x in cor_shape: #generating a list with all the correlation values
    for y in cor_shape:
        point = cor_tab.iloc[x,y] 
        if point not in tlist:
            tlist.append(point)
        else:
            continue
    tlist = sorted(tlist, reverse= True)

hcp = tlist[0:4] #highest correlations (positive)
hcn = tlist[-4:] #highest correlations (negative)

# %%
def getIndexes(dfObj, value):
    ''' Get index positions of value in dataframe i.e. dfObj.'''
    listOfPos = list()
    # Get bool dataframe with True at positions where the given value exists
    result = dfObj.isin([value])
    # Get list of columns that contains the value
    seriesObj = result.any()
    columnNames = list(seriesObj[seriesObj == True].index)
    # Iterate over list of columns and fetch the rows indexes where value exists
    for col in columnNames:
        rows = list(result[col][result[col] == True].index)
        for row in rows:
            listOfPos.append((row, col, value))
    # Return a list of tuples indicating the positions of value in the dataframe
    return listOfPos

# %%
cords_p = []
for i in hcp: #highest positive correlations with their respective name of the row/column
    g = getIndexes(cor_tab,i)
    cords_p.append(g)
pc = [[cords_p[0:4][0][0]],[cords_p[0:4][1][0]],[cords_p[0:4][2][0]],[cords_p[0:4][3][0]]]
c
# Out:
# [[('YearsWithCurrManager', 'YearsAtCompany', 0.7692124251006943)],
#  [('TotalWorkingYears', 'Age', 0.6806613847683006)],
#  [('YearsAtCompany', 'TotalWorkingYears', 0.62770314660217)],
#  [('YearsSinceLastPromotion', 'YearsAtCompany', 0.6184088652176152)]]

# %%
cords_n = []
for i in hcn: #highest negative correlations with their respective name of the row/column
    g = getIndexes(cor_tab,i)
    cords_n.append(g)
nc = [[cords_n[0:4][0][0]],[cords_n[0:4][1][0]],[cords_n[0:4][2][0]],[cords_n[0:4][3][0]]]
nc
# Out:
# [[('YearsAtCompany', 'JobLevel', -0.06421877428823006)],
#  [('TrainingTimesLastYear', 'StockOptionLevel', -0.06990176082577283)],
#  [('YearsWithCurrManager', 'NumCompaniesWorked', -0.1096666281066744)],
#  [('YearsAtCompany', 'NumCompaniesWorked', -0.11795890364728069)]]

# %%
pd.plotting.scatter_matrix(data_nums_cor, alpha=0.5, figsize=(20,20), 
                           diagonal='hist', marker='.', 
                           density_kwds=None, hist_kwds=None, range_padding=0.4);
